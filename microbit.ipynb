# %% [markdown]
# <h1>Table of Contents<span class="tocSkip"></span></h1>
# <div class="toc" style="margin-top: 1em;"><ul class="toc-item"><li><span><a href="#Help-using-this-notebook" data-toc-modified-id="Help-using-this-notebook-1"><span class="toc-item-num">1&nbsp;&nbsp;</span>Help using this notebook</a></span></li><li><span><a href="#Hello-World" data-toc-modified-id="Hello-World-2"><span class="toc-item-num">2&nbsp;&nbsp;</span>Hello World</a></span></li><li><span><a href="#Displaying-Images" data-toc-modified-id="Displaying-Images-3"><span class="toc-item-num">3&nbsp;&nbsp;</span>Displaying Images</a></span></li><li><span><a href="#Creating-Images" data-toc-modified-id="Creating-Images-4"><span class="toc-item-num">4&nbsp;&nbsp;</span>Creating Images</a></span></li><li><span><a href="#NeoPixels" data-toc-modified-id="NeoPixels-5"><span class="toc-item-num">5&nbsp;&nbsp;</span>NeoPixels</a></span></li><li><span><a href="#Animation" data-toc-modified-id="Animation-6"><span class="toc-item-num">6&nbsp;&nbsp;</span>Animation</a></span></li></ul></div>

# %% [markdown]
# ![microbit_header_002.png](attachment:microbit_header_002.png)

# %% [markdown]
# # Micro:Bit Python **Challenge Booklet 1**

# %% [markdown]
# ## Help using this notebook

# %% [markdown]
# There are many ways to program the BBC Micro:bit. Here we are use a fabulous technology called **Jupyter Notebooks**.
#
# **Jupyter Notebooks** let you code live in a web browser and see the results quickly on an attached Micro:Bit.
#
# Features:
# * Error messages get reported live in the notebook
# * You can write notes
# * Create live programs
# * Present your work.
#
# The blocks on the page are called 'cells'. You can run code in a cell by pressing <kbd>ctrl</kbd> + <kbd>return</kbd>.

# %% [markdown]
# ## Hello World

# %%
from microbit import *
display.scroll("Mr Grant!")

# %% [markdown]
# **Activity: Change the scrolling message**
#
# Using the code as a starting point above change the message that is displayed.

# %%
# This is the solution

# %%
# insert your code here

# %% [markdown]
# ## Displaying Images

# %% [markdown]
# ## Creating Images

# %% [markdown]
# **Activity: Change the scrolling message**
#
# Using the code as a starting point above change the message that is displayed.

# %%
# Press ctrl + enter to run this cell
from microbit import *
display.show(Image.PACMAN)

# %% [markdown]
# ## NeoPixels

# %% [markdown]
# You will need a micro:bit with a neopixel or a zip halo attached.
#
# Run the code below. Select the cell and press: <kbd>ctrl</kbd> + <kbd>return</kbd>

# %%
from microbit import *
import neopixel
from random import randint

def zipHaloReset():
    np = neopixel.NeoPixel(pin0, 24)
    for pixel_id in range(0, len(np)):
        red = 0
        green = 0
        blue = 0
        # Assign the current LED a random red, green and blue value between 0 and 60
        np[pixel_id] = (red, green, blue)
        # Display the current pixel data on the Neopixel strip
        np.show()
def zipHaloRed():
    np = neopixel.NeoPixel(pin0, 24)
    for pixel_id in range(0, len(np)):
        red = 255
        green = 0
        blue = 0
        # Assign the current LED a random red, green and blue value between 0 and 60
        np[pixel_id] = (red, green, blue)
        # Display the current pixel data on the Neopixel strip
        np.show()
def zipHaloBlue():
    np = neopixel.NeoPixel(pin0, 24)
    for pixel_id in range(0, len(np)):
        red = 0
        green = 0
        blue = 255
        # Assign the current LED a random red, green and blue value between 0 and 60
        np[pixel_id] = (red, green, blue)
        # Display the current pixel data on the Neopixel strip
        np.show()
def zipHaloRGBColor(r, g, b):
    np = neopixel.NeoPixel(pin0, 24)
    for pixel_id in range(0, len(np)):
        red = r
        green = g
        blue = b
        # Assign the current LED a random red, green and blue value between 0 and 60
        np[pixel_id] = (red, green, blue)
        # Display the current pixel data on the Neopixel strip
        np.show()

#zipHaloReset()
zipHaloReset()
zipHaloRed()
sleep(1000)
zipHaloBlue()
sleep(1000)
zipHaloRGBColor(255,255,255)
sleep(1000)
zipHaloReset()

# %% [markdown]
# ## Animation

# %% [markdown]
# Nothing to see here.
